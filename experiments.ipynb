# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("train_data.csv",parse_dates=['Created','DepartureTime','CancelTime'],encoding="utf-8")

# %%
df.head()
# Out:
#                   Created CancelTime       DepartureTime    BillID   TicketID  \
# 0 2022-10-23 09:38:49.110        NaT 2022-11-02 23:59:00  39710203  1091777.0
# 1 2022-08-15 14:51:43.160        NaT 2022-08-18 04:15:00  38689463  1070902.0
# 2 2022-09-20 17:25:27.250        NaT 2022-09-21 11:00:00  39245173  7624237.0
# 3 2022-06-25 11:32:53.980        NaT 2022-06-26 08:30:00  37957585  2867547.0
# 4 2022-06-01 11:30:53.633        NaT 2022-06-02 23:00:00  37584530  7212559.0
#
#    ReserveStatus    UserID   Male      Price  CouponDiscount  ... Domestic  \
# 0              5  122885.0   True  6600000.0         34425.0  ...        1
# 1              5  876925.0   True  9500000.0             0.0  ...        1
# 2              3  916640.0  False  2000000.0             0.0  ...        1
# 3              2       NaN  False    40000.0             0.0  ...        1
# 4              3       NaN   True  1130000.0             0.0  ...        1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101017 entries, 0 to 101016
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Created               101017 non-null  datetime64[ns]
#  1   CancelTime            15326 non-null   datetime64[ns]
#  2   DepartureTime         101017 non-null  datetime64[ns]
#  3   BillID                101017 non-null  int64
#  4   TicketID              101017 non-null  float64
#  5   ReserveStatus         101017 non-null  int64
#  6   UserID                42543 non-null   float64
#  7   Male                  101017 non-null  bool
#  8   Price                 101017 non-null  float64
#  9   CouponDiscount        101017 non-null  float64
#  10  From                  101017 non-null  object
#  11  To                    101017 non-null  object
#  12  Domestic              101017 non-null  int64
#  13  VehicleType           93473 non-null   object
# ...

# %%
df.shape
# Out:
# (101017, 22)

# %%
df=df[:25000]

# %%
df.head()
# Out:
#                   Created CancelTime       DepartureTime    BillID   TicketID  \
# 0 2022-10-23 09:38:49.110        NaT 2022-11-02 23:59:00  39710203  1091777.0
# 1 2022-08-15 14:51:43.160        NaT 2022-08-18 04:15:00  38689463  1070902.0
# 2 2022-09-20 17:25:27.250        NaT 2022-09-21 11:00:00  39245173  7624237.0
# 3 2022-06-25 11:32:53.980        NaT 2022-06-26 08:30:00  37957585  2867547.0
# 4 2022-06-01 11:30:53.633        NaT 2022-06-02 23:00:00  37584530  7212559.0
#
#    ReserveStatus    UserID   Male      Price  CouponDiscount  ... Domestic  \
# 0              5  122885.0   True  6600000.0         34425.0  ...        1
# 1              5  876925.0   True  9500000.0             0.0  ...        1
# 2              3  916640.0  False  2000000.0             0.0  ...        1
# 3              2       NaN  False    40000.0             0.0  ...        1
# 4              3       NaN   True  1130000.0             0.0  ...        1
#
# ...

# %%
df.shape
# Out:
# (25000, 22)

# %%
df.describe()
# Out:
#                              Created                     CancelTime  \
# count                          25000                           3753
# mean   2022-07-20 22:45:38.819801344  2022-07-31 01:49:33.896269568
# min       2022-01-31 21:16:08.950000     2022-02-01 09:45:27.923000
# 25%    2022-05-23 21:07:30.204499968  2022-06-15 16:15:47.849999872
# 50%       2022-08-04 20:34:45.372000  2022-08-25 18:37:03.332999936
# 75%    2022-09-24 14:11:55.175749888  2022-09-24 23:43:11.976999936
# max       2022-11-03 00:03:22.870000     2022-11-02 23:02:21.253000
# std                              NaN                            NaN
#
#                     DepartureTime        BillID      TicketID  ReserveStatus  \
# count                       25000  2.500000e+04  2.500000e+04   25000.000000
# mean   2022-07-26 22:08:38.352000  3.833540e+07  4.955747e+06       3.160120
# min           2022-02-01 14:00:00  3.591104e+07  1.015941e+06       2.000000
# ...

# %%
# data preprocessing and feature engineering
df.drop_duplicates(keep="first",inplace=True)

# %%
# removing the useless columns
df.drop(['UserID','NationalCode','BuyerMobile','HashEmail','CancelTime','HashPassportNumber_p','VehicleType','VehicleClass'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Created           0
# DepartureTime     0
# BillID            0
# TicketID          0
# ReserveStatus     0
# Male              0
# Price             0
# CouponDiscount    0
# From              0
# To                0
# Domestic          0
# TripReason        0
# Vehicle           0
# Cancel            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Created', 'DepartureTime', 'BillID', 'TicketID', 'ReserveStatus',
#        'Male', 'Price', 'CouponDiscount', 'From', 'To', 'Domestic',
#        'TripReason', 'Vehicle', 'Cancel'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Created         25000 non-null  datetime64[ns]
#  1   DepartureTime   25000 non-null  datetime64[ns]
#  2   BillID          25000 non-null  int64
#  3   TicketID        25000 non-null  float64
#  4   ReserveStatus   25000 non-null  int64
#  5   Male            25000 non-null  bool
#  6   Price           25000 non-null  float64
#  7   CouponDiscount  25000 non-null  float64
#  8   From            25000 non-null  object
#  9   To              25000 non-null  object
#  10  Domestic        25000 non-null  int64
#  11  TripReason      25000 non-null  object
#  12  Vehicle         25000 non-null  object
#  13  Cancel          25000 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(4), object(4)
# memory usage: 2.5+ MB

# %%
# split the data into input nad output
x=df.drop("Cancel",axis=1)
x.head()
# Out:
#                   Created       DepartureTime    BillID   TicketID  \
# 0 2022-10-23 09:38:49.110 2022-11-02 23:59:00  39710203  1091777.0
# 1 2022-08-15 14:51:43.160 2022-08-18 04:15:00  38689463  1070902.0
# 2 2022-09-20 17:25:27.250 2022-09-21 11:00:00  39245173  7624237.0
# 3 2022-06-25 11:32:53.980 2022-06-26 08:30:00  37957585  2867547.0
# 4 2022-06-01 11:30:53.633 2022-06-02 23:00:00  37584530  7212559.0
#
#    ReserveStatus   Male      Price  CouponDiscount   From                  To  \
# 0              5   True  6600000.0         34425.0  گرگان               تهران
# 1              5   True  9500000.0             0.0   مشهد               تهران
# 2              3  False  2000000.0             0.0  شیراز               اهواز
# 3              2  False    40000.0             0.0  تبریز                جلفا
# 4              3   True  1130000.0             0.0  تهران  نجف آباد (اصفهان )
#
#    Domestic TripReason Vehicle
# 0         1       Work   Plane
# ...

# %%
y=df["Cancel"]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 24995    0
# 24996    0
# 24997    0
# 24998    0
# 24999    0
# Name: Cancel, Length: 25000, dtype: int64

# %%
df["Cancel"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# split the data into train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)
print(x_train.shape)
print(x_test.shape)
# Out:
# (20000, 13)
# (5000, 13)

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount    From              To  \
# 16715              2  True  2457500.0             0.0  زاهدان           تهران
# 18404              2  True  6630500.0             0.0     کرج            مشهد
# 24558              3  True   950000.0             0.0   گرگان  مشهد (خراسان )
# 24922              2  True   426500.0             0.0   تهران           سمنان
# 3364               3  True  1340000.0             0.0     کرج          اصفهان
#
#        Domestic TripReason Vehicle
# ...

# %%
px.box(data_frame=x_train,x="CouponDiscount")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\hotel_project\venv\lib\site-packages\IPython\core\formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File e:\hotel_project\venv\lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File e:\hotel_project\venv\lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
# ...

# %%
# replace the outliers
df["CouponDiscount"].mode()
# Out:
# 0    0.0
# Name: CouponDiscount, dtype: float64

# %%
# manage outlier in CouponDiscount
x_train.CouponDiscount.describe()
x_train.loc[((x_train.CouponDiscount <0) | (x_train.CouponDiscount == max(x_train.CouponDiscount))) , 'CouponDiscount']= 0
df.CouponDiscount.describe()
df.loc[((df.CouponDiscount <0) | (df.CouponDiscount == max(df.CouponDiscount))) , 'CouponDiscount']= 0

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount    From              To  \
# 16715              2  True  2457500.0             0.0  زاهدان           تهران
# 18404              2  True  6630500.0             0.0     کرج            مشهد
# 24558              3  True   950000.0             0.0   گرگان  مشهد (خراسان )
# 24922              2  True   426500.0             0.0   تهران           سمنان
# 3364               3  True  1340000.0             0.0     کرج          اصفهان
#
#        Domestic TripReason Vehicle
# ...

# %%
# Combine 'From' and 'To' columns to create a list of all cities
all_cities = df['From'].tolist() + df['To'].tolist()

# Create a set of unique cities and convert it back to a list
unique_cities = list(set(all_cities))

# %%
from sklearn.preprocessing import LabelEncoder

# %%
city_enc=LabelEncoder()

# %%
city_enc.fit(unique_cities)
# Out:
# LabelEncoder()

# %%
x_train["From_encoded"]=city_enc.transform(x_train["From"])
x_train["to_encoded"]=city_enc.transform(x_train["To"])

# %%
import pickle
pickle.dump(city_enc,open("city_encoder.pkl","wb"))

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount    From              To  \
# 16715              2  True  2457500.0             0.0  زاهدان           تهران
# 18404              2  True  6630500.0             0.0     کرج            مشهد
# 24558              3  True   950000.0             0.0   گرگان  مشهد (خراسان )
# 24922              2  True   426500.0             0.0   تهران           سمنان
# 3364               3  True  1340000.0             0.0     کرج          اصفهان
#
#        Domestic TripReason Vehicle  From_encoded  to_encoded
# ...

# %%
df.head()
# Out:
#                   Created       DepartureTime    BillID   TicketID  \
# 0 2022-10-23 09:38:49.110 2022-11-02 23:59:00  39710203  1091777.0
# 1 2022-08-15 14:51:43.160 2022-08-18 04:15:00  38689463  1070902.0
# 2 2022-09-20 17:25:27.250 2022-09-21 11:00:00  39245173  7624237.0
# 3 2022-06-25 11:32:53.980 2022-06-26 08:30:00  37957585  2867547.0
# 4 2022-06-01 11:30:53.633 2022-06-02 23:00:00  37584530  7212559.0
#
#    ReserveStatus   Male      Price  CouponDiscount   From                  To  \
# 0              5   True  6600000.0         34425.0  گرگان               تهران
# 1              5   True  9500000.0             0.0   مشهد               تهران
# 2              3  False  2000000.0             0.0  شیراز               اهواز
# 3              2  False    40000.0             0.0  تبریز                جلفا
# 4              3   True  1130000.0             0.0  تهران  نجف آباد (اصفهان )
#
#    Domestic TripReason Vehicle  Cancel  From_encoded  to_encoded
# ...

# %%
# Fill missing values with -1
x_train['From_encoded'].fillna(-1, inplace=True)
x_train['to_encoded'].fillna(-1, inplace=True)
# Out:
# C:\Windows\Temp\ipykernel_16396\151096872.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train['From_encoded'].fillna(-1, inplace=True)
# C:\Windows\Temp\ipykernel_16396\151096872.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
x_test["From_encoded"]=city_enc.transform(x_test["From"])
x_test["to_encoded"]=city_enc.transform(x_test["To"])
df["From_encoded"]=city_enc.transform(df["From"])
df["to_encoded"]=city_enc.transform(df["To"])

# %%
# Fill missing values with -1
x_test['From_encoded'].fillna(-1, inplace=True)
x_test['to_encoded'].fillna(-1, inplace=True)
# Out:
# C:\Windows\Temp\ipykernel_16396\4142709344.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_test['From_encoded'].fillna(-1, inplace=True)
# C:\Windows\Temp\ipykernel_16396\4142709344.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# now we delete the from and to columns
x_train = x_train.drop(labels=['From','To'], axis=1)
x_test = x_test.drop(labels=['From','To'], axis=1)
df = df.drop(labels=['From','To'], axis=1)

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount  Domestic TripReason  \
# 16715              2  True  2457500.0             0.0         1       Work
# 18404              2  True  6630500.0             0.0         1        Int
# 24558              3  True   950000.0             0.0         1       Work
# 24922              2  True   426500.0             0.0         1        Int
# 3364               3  True  1340000.0             0.0         1       Work
#
#       Vehicle  From_encoded  to_encoded
# 16715   Train           115          70
# ...

# %%
df.head()
# Out:
#                   Created       DepartureTime    BillID   TicketID  \
# 0 2022-10-23 09:38:49.110 2022-11-02 23:59:00  39710203  1091777.0
# 1 2022-08-15 14:51:43.160 2022-08-18 04:15:00  38689463  1070902.0
# 2 2022-09-20 17:25:27.250 2022-09-21 11:00:00  39245173  7624237.0
# 3 2022-06-25 11:32:53.980 2022-06-26 08:30:00  37957585  2867547.0
# 4 2022-06-01 11:30:53.633 2022-06-02 23:00:00  37584530  7212559.0
#
#    ReserveStatus   Male      Price  CouponDiscount  Domestic TripReason  \
# 0              5   True  6600000.0         34425.0         1       Work
# 1              5   True  9500000.0             0.0         1        Int
# 2              3  False  2000000.0             0.0         1       Work
# 3              2  False    40000.0             0.0         1        Int
# 4              3   True  1130000.0             0.0         1        Int
#
#   Vehicle  Cancel  From_encoded  to_encoded
# 0   Plane       0           253          70
# ...

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount  Domestic TripReason  \
# 16715              2  True  2457500.0             0.0         1       Work
# 18404              2  True  6630500.0             0.0         1        Int
# 24558              3  True   950000.0             0.0         1       Work
# 24922              2  True   426500.0             0.0         1        Int
# 3364               3  True  1340000.0             0.0         1       Work
#
#       Vehicle  From_encoded  to_encoded
# 16715   Train           115          70
# ...

# %%
def label_encode_boolean_column(df, column_name):
    df.loc[df[column_name] == True, column_name] = 1
    df.loc[df[column_name] == False, column_name] = 0
    df[column_name] = df[column_name].astype(int)
    return df

x_train = label_encode_boolean_column(x_train, 'Male')
x_test = label_encode_boolean_column(x_test, 'Male')
df = label_encode_boolean_column(df, 'Male')
# Out:
# C:\Windows\Temp\ipykernel_16396\1243995777.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df[column_name] == True, column_name] = 1
# C:\Windows\Temp\ipykernel_16396\1243995777.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df[column_name] == True, column_name] = 1
# C:\Windows\Temp\ipykernel_16396\1243995777.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   df.loc[df[column_name] == True, column_name] = 1

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount  Domestic TripReason  \
# 16715              2     1  2457500.0             0.0         1       Work
# 18404              2     1  6630500.0             0.0         1        Int
# 24558              3     1   950000.0             0.0         1       Work
# 24922              2     1   426500.0             0.0         1        Int
# 3364               3     1  1340000.0             0.0         1       Work
#
#       Vehicle  From_encoded  to_encoded
# 16715   Train           115          70
# ...

# %%
df.head()
# Out:
#                   Created       DepartureTime    BillID   TicketID  \
# 0 2022-10-23 09:38:49.110 2022-11-02 23:59:00  39710203  1091777.0
# 1 2022-08-15 14:51:43.160 2022-08-18 04:15:00  38689463  1070902.0
# 2 2022-09-20 17:25:27.250 2022-09-21 11:00:00  39245173  7624237.0
# 3 2022-06-25 11:32:53.980 2022-06-26 08:30:00  37957585  2867547.0
# 4 2022-06-01 11:30:53.633 2022-06-02 23:00:00  37584530  7212559.0
#
#    ReserveStatus  Male      Price  CouponDiscount  Domestic TripReason  \
# 0              5     1  6600000.0         34425.0         1       Work
# 1              5     1  9500000.0             0.0         1        Int
# 2              3     0  2000000.0             0.0         1       Work
# 3              2     0    40000.0             0.0         1        Int
# 4              3     1  1130000.0             0.0         1        Int
#
#   Vehicle  Cancel  From_encoded  to_encoded
# 0   Plane       0           253          70
# 1   Plane       0           189          70
# ...

# %%
# encoding Vehicle & TripReason
veh_encoder = LabelEncoder()
    
    
x_train["Vehicle"]= veh_encoder.fit_transform(x_train["Vehicle"])
x_test["Vehicle"]= veh_encoder.transform(x_test["Vehicle"])

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount  Domestic TripReason  \
# 16715              2     1  2457500.0             0.0         1       Work
# 18404              2     1  6630500.0             0.0         1        Int
# 24558              3     1   950000.0             0.0         1       Work
# 24922              2     1   426500.0             0.0         1        Int
# 3364               3     1  1340000.0             0.0         1       Work
#
#        Vehicle  From_encoded  to_encoded
# 16715        3           115          70
# ...

# %%
x_train["TripReason"].unique()
# Out:
# array([1, 0])

# %%
import pickle 
pickle.dump(veh_encoder,open("veh_encoder.pkl","wb"))

# %%
trip_enc=LabelEncoder()
x_train["TripReason"]= trip_enc.fit_transform(x_train["TripReason"]) 
x_test["TripReason"]= trip_enc.transform(x_test["TripReason"])

# %%
x_train.head()
# Out:
#                       Created       DepartureTime    BillID   TicketID  \
# 16715 2022-09-28 10:06:47.487 2022-09-29 13:50:00  39383577  3036284.0
# 18404 2022-07-24 18:35:44.120 2022-07-29 16:35:00  38404665  2916206.0
# 24558 2022-04-27 11:05:20.983 2022-04-27 21:30:00  37066780  7072159.0
# 24922 2022-07-12 00:52:00.020 2022-07-14 08:00:00  38222666  2896788.0
# 3364  2022-10-20 15:11:25.663 2022-10-21 16:00:00  39679742  7737604.0
#
#        ReserveStatus  Male      Price  CouponDiscount  Domestic  TripReason  \
# 16715              2     1  2457500.0             0.0         1           1
# 18404              2     1  6630500.0             0.0         1           0
# 24558              3     1   950000.0             0.0         1           1
# 24922              2     1   426500.0             0.0         1           0
# 3364               3     1  1340000.0             0.0         1           1
#
#        Vehicle  From_encoded  to_encoded
# ...

# %%
import pickle
pickle.dump(trip_enc,open("trip_encoder.pkl","wb"))

# %%
def calculate_days_difference(df):
    df['Days_Difference'] = (df['DepartureTime'] - df['Created']).dt.days
    df.drop(columns=['DepartureTime','Created'], inplace=True, axis=1)
    return df

x_train = calculate_days_difference(x_train)
x_test = calculate_days_difference(x_test)
df=calculate_days_difference(df)

# %%
x_train.head()
# Out:
#          BillID   TicketID  ReserveStatus  Male      Price  CouponDiscount  \
# 16715  39383577  3036284.0              2     1  2457500.0             0.0
# 18404  38404665  2916206.0              2     1  6630500.0             0.0
# 24558  37066780  7072159.0              3     1   950000.0             0.0
# 24922  38222666  2896788.0              2     1   426500.0             0.0
# 3364   39679742  7737604.0              3     1  1340000.0             0.0
#
#        Domestic  TripReason  Vehicle  From_encoded  to_encoded  \
# 16715         1           1        3           115          70
# 18404         1           0        3           240         189
# 24558         1           1        0           253         190
# 24922         1           0        3            70         127
# 3364          1           1        0           240          27
#
#        Days_Difference
# 16715                1
# 18404                4
# 24558                0
# 24922                2
# ...

# %%
df.head()
# Out:
#      BillID   TicketID  ReserveStatus  Male      Price  CouponDiscount  \
# 0  39710203  1091777.0              5     1  6600000.0         34425.0
# 1  38689463  1070902.0              5     1  9500000.0             0.0
# 2  39245173  7624237.0              3     0  2000000.0             0.0
# 3  37957585  2867547.0              2     0    40000.0             0.0
# 4  37584530  7212559.0              3     1  1130000.0             0.0
#
#    Domestic  TripReason  Vehicle  Cancel  From_encoded  to_encoded  \
# 0         1           1        2       0           253          70
# 1         1           0        2       0           189          70
# 2         1           1        0       0           145          33
# 3         1           0        3       0            65          73
# 4         1           0        0       0            70         207
#
#    Days_Difference
# 0               10
# 1                2
# 2                0
# 3                0
# 4                1

# %%
def add_family_member_feature(df):

    grouped_data = df.groupby('BillID')['Male'].nunique().reset_index()
    grouped_data = grouped_data.rename(columns={'Male': 'Family_Members'})
    df = pd.merge(df, grouped_data, on='BillID', how='left')
    
    return df

x_train = add_family_member_feature(x_train)
x_test = add_family_member_feature(x_test)
df=add_family_member_feature(df)

# %%
x_train.head()
# Out:
#      BillID   TicketID  ReserveStatus  Male      Price  CouponDiscount  \
# 0  39383577  3036284.0              2     1  2457500.0             0.0
# 1  38404665  2916206.0              2     1  6630500.0             0.0
# 2  37066780  7072159.0              3     1   950000.0             0.0
# 3  38222666  2896788.0              2     1   426500.0             0.0
# 4  39679742  7737604.0              3     1  1340000.0             0.0
#
#    Domestic  TripReason  Vehicle  From_encoded  to_encoded  Days_Difference  \
# 0         1           1        3           115          70                1
# 1         1           0        3           240         189                4
# 2         1           1        0           253         190                0
# 3         1           0        3            70         127                2
# 4         1           1        0           240          27                1
#
#    Family_Members
# 0               1
# 1               1
# 2               1
# ...

# %%
df.head()
# Out:
#      BillID   TicketID  ReserveStatus  Male      Price  CouponDiscount  \
# 0  39710203  1091777.0              5     1  6600000.0         34425.0
# 1  38689463  1070902.0              5     1  9500000.0             0.0
# 2  39245173  7624237.0              3     0  2000000.0             0.0
# 3  37957585  2867547.0              2     0    40000.0             0.0
# 4  37584530  7212559.0              3     1  1130000.0             0.0
#
#    Domestic  TripReason  Vehicle  Cancel  From_encoded  to_encoded  \
# 0         1           1        2       0           253          70
# 1         1           0        2       0           189          70
# 2         1           1        0       0           145          33
# 3         1           0        3       0            65          73
# 4         1           0        0       0            70         207
#
#    Days_Difference  Family_Members
# 0               10               1
# 1                2               1
# ...

# %%
def count_tickets_per_order(df):
    # Group data by "BillId" and count the number of distinct values in "TicketId" column
    ticket_counts = df.groupby('BillID')['TicketID'].nunique().reset_index()
    # Rename the column
    ticket_counts = ticket_counts.rename(columns={'TicketID': 'Ticket_Count'})
    # Merge the ticket counts with the original data
    df = pd.merge(df, ticket_counts, on='BillID', how='left')
    
    return df

x_train = count_tickets_per_order(x_train)
x_test = count_tickets_per_order(x_test)
df=count_tickets_per_order(df)

# %%
x_train.head()
# Out:
#      BillID   TicketID  ReserveStatus  Male      Price  CouponDiscount  \
# 0  39383577  3036284.0              2     1  2457500.0             0.0
# 1  38404665  2916206.0              2     1  6630500.0             0.0
# 2  37066780  7072159.0              3     1   950000.0             0.0
# 3  38222666  2896788.0              2     1   426500.0             0.0
# 4  39679742  7737604.0              3     1  1340000.0             0.0
#
#    Domestic  TripReason  Vehicle  From_encoded  to_encoded  Days_Difference  \
# 0         1           1        3           115          70                1
# 1         1           0        3           240         189                4
# 2         1           1        0           253         190                0
# 3         1           0        3            70         127                2
# 4         1           1        0           240          27                1
#
#    Family_Members  Ticket_Count
# 0               1             1
# ...

# %%
df.head()
# Out:
#      BillID   TicketID  ReserveStatus  Male      Price  CouponDiscount  \
# 0  39710203  1091777.0              5     1  6600000.0         34425.0
# 1  38689463  1070902.0              5     1  9500000.0             0.0
# 2  39245173  7624237.0              3     0  2000000.0             0.0
# 3  37957585  2867547.0              2     0    40000.0             0.0
# 4  37584530  7212559.0              3     1  1130000.0             0.0
#
#    Domestic  TripReason  Vehicle  Cancel  From_encoded  to_encoded  \
# 0         1           1        2       0           253          70
# 1         1           0        2       0           189          70
# 2         1           1        0       0           145          33
# 3         1           0        3       0            65          73
# 4         1           0        0       0            70         207
#
#    Days_Difference  Family_Members  Ticket_Count
# 0               10               1             1
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train.drop(["BillID","TicketID"],axis=1,inplace=True)
df.drop(["BillID","TicketID"],axis=1,inplace=True)

# %%
x_test.drop(["BillID","TicketID"],axis=1,inplace=True)

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_test=scaler.transform(x_test)

# %%
import mlflow

# %%
mlflow.set_experiment("hotel_cancellation_prediction")
# Out:
# 2024/05/05 20:46:47 INFO mlflow.tracking.fluent: Experiment with name 'hotel_cancellation_prediction' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///d:/intern_pro/mlruns/501142815481220808', creation_time=1714922207781, experiment_id='501142815481220808', last_update_time=1714922207781, lifecycle_stage='active', name='hotel_cancellation_prediction', tags={}>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier

# %%
pipelines={
    "logreg":Pipeline([("classifier",LogisticRegression())]),
    "dt":Pipeline([("classifier",DecisionTreeClassifier())]),
    "ranfor":Pipeline([("classifier",RandomForestClassifier())]),
    "svc":Pipeline([("classifier",SVC())]),
    "xg":Pipeline([("classifier",XGBClassifier())])
}

param_grids={
    "logreg":[{'classifier__C': [0.1, 1, 10], 
            'classifier__penalty': ['l2']
            }],

    "dt":[{
        'classifier__max_depth': [None, 5, 10]
    }],

    
    "ranfor":[{
        'classifier__n_estimators': [50, 100, 200]
    }],

    "svc":[
        
        
        {
            'classifier__kernel' : ['poly'], 
            'classifier__degree' : [2, 3, 4, 5], 
            'classifier__C' : [0.1, 0.01, 1, 10, 100]
        },

        {
            'classifier__kernel' : ['linear'], 
            'classifier__C' : [0.1, 0.01, 1, 10, 100]
        }
    ],

    "xg":[{

        'n_estimators': [50, 100, 150],
        'learning_rate': [0.01, 0.1, 0.5],
        'max_depth': [2, 3, 4, 5],
        'subsample': [0.5, 0.8, 1.0],
        'colsample_bytree': [0.1, 0.2, 0.3, 0.5],
        'colsample_bylevel' : [0.1, 0.2, 0.3, 0.5],
        'min_child_weight': [1, 3, 5,7]
    }]

    
}

# %%
import os
import joblib
best_models={}
for i in pipelines.keys():
    print("*"*10,i,"*"*10)
    grid_search=GridSearchCV(estimator=pipelines[i],
    param_grid=param_grids[i],
    cv=5,
    scoring="accuracy",
    return_train_score=True,
    verbose=1)

    mlflow.sklearn.autolog(max_tuning_runs=None)
    with mlflow.start_run() as run:
        # %time grid_search.fit(x_train,y_train)
    print("train score",grid_search.best_score_)
    print("test score",grid_search.score(x_test,y_test))
    best_models[i]=grid_search.best_estimator_
    print()
    model_dir="best_models"
    os.makedirs(model_dir,exist_ok=True)
    model_path=os.path.join(model_dir,f"{i}.pkl")
    joblib.dump(grid_search.best_estimator_,model_path)
    model_size=os.path.getsize(model_path)
# Out:
# ********** logreg **********
# 2024/05/05 20:47:43 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# 2024/05/05 20:48:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "d:\intern_pro\venv\lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils."
# CPU times: total: 1.25 s
# Wall time: 28.6 s
# train score 0.96085
# test score 0.9586
#
# ********** dt **********
# 2024/05/05 20:48:12 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'flatten'
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# CPU times: total: 594 ms
# Wall time: 8.1 s
# train score 0.9805499999999998
# test score 0.9816
#
# ********** ranfor **********
# ...

# %%
import joblib

# Load the model
mod= joblib.load("best_models\logreg.pkl")

# %%
mod.predict([[2	,1	,2457500.0,	0.0	,1,	1	,3	,115	,70,	1,	1,	1]])
# Out:
# array([0], dtype=int64)

# %%
import pickle
pickle.dump(scaler,open("scaler.pkl","wb"))

# %%
df.head()
# Out:
#    ReserveStatus  Male      Price  CouponDiscount  Domestic  TripReason  \
# 0              5     1  6600000.0         34425.0         1           1
# 1              5     1  9500000.0             0.0         1           0
# 2              3     0  2000000.0             0.0         1           1
# 3              2     0    40000.0             0.0         1           0
# 4              3     1  1130000.0             0.0         1           0
#
#    Vehicle  Cancel  From_encoded  to_encoded  Days_Difference  Family_Members  \
# 0        2       0           253          70               10               1
# 1        2       0           189          70                2               1
# 2        0       0           145          33                0               1
# 3        3       0            65          73                0               2
# 4        0       0            70         207                1               1
#
#    Ticket_Count
# 0             1
# 1             1
# ...

# %%
df.to_csv("final_data.csv")
